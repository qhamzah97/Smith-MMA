# %% [markdown]
# # XGBoost

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

import xgboost as xgb

# %%
# Load and preprocess the data
submission = pd.read_csv('Submission_Files/submission_format.csv')
test_set_feat = pd.read_csv('Data/test_set_features.csv', index_col='respondent_id')
train_set_feat = pd.read_csv('Data/training_set_features.csv', index_col='respondent_id')
train_set_lab = pd.read_csv('Data/training_set_labels.csv', index_col='respondent_id')

# %%
# Join train_set_feat and train_set_lab by 'respondent_id' column
train_data = train_set_feat.join(train_set_lab)

# Display the joined dataframe
train_data.head()
# Out:
#                h1n1_concern  h1n1_knowledge  ...  h1n1_vaccine  seasonal_vaccine
# respondent_id                                ...
# 0                       1.0             0.0  ...             0                 0
# 1                       3.0             2.0  ...             0                 1
# 2                       1.0             1.0  ...             0                 0
# 3                       1.0             1.0  ...             0                 1
# 4                       2.0             1.0  ...             0                 0
#
# [5 rows x 37 columns]

# %%
# View Proportion of Missing Data (Descending)
train_data.isna().sum().sort_values(ascending=False)/len(train_data)
# Out:
# employment_occupation          0.504362
# employment_industry            0.499120
# health_insurance               0.459580
# income_poverty                 0.165612
# doctor_recc_h1n1               0.080878
# doctor_recc_seasonal           0.080878
# rent_or_own                    0.076459
# employment_status              0.054780
# marital_status                 0.052720
# education                      0.052683
# chronic_med_condition          0.036358
# child_under_6_months           0.030704
# health_worker                  0.030104
# opinion_seas_sick_from_vacc    0.020107
# opinion_seas_risk              0.019246
# opinion_seas_vacc_effective    0.017299
# opinion_h1n1_sick_from_vacc    0.014790
# opinion_h1n1_vacc_effective    0.014640
# opinion_h1n1_risk              0.014528
# household_adults               0.009323
# household_children             0.009323
# behavioral_avoidance           0.007788
# behavioral_touch_face          0.004793
# h1n1_knowledge                 0.004343
# h1n1_concern                   0.003445
# behavioral_large_gatherings    0.003258
# behavioral_outside_home        0.003070
# behavioral_antiviral_meds      0.002658
# behavioral_wash_hands          0.001573
# behavioral_face_mask           0.000711
# sex                            0.000000
# race                           0.000000
# age_group                      0.000000
# hhs_geo_region                 0.000000
# census_msa                     0.000000
# h1n1_vaccine                   0.000000
# seasonal_vaccine               0.000000
# dtype: float64

# %% [markdown]
# ## Identify the categorical features that require one-hot encoding or rank order
#
# #### Binary
# - 'sex'
# - 'marital_status'
# - 'rent_or_own'
#
# #### Rank Order
# - 'age_group'
# - 'education'
# - 'income_poverty'
# - 'employment_status'
# - 'census_msa'
#
# #### One Hot Encoding (Dummies)
# - 'race'
# - 'hhs_geo_region'
# - 'employment_industry'
# - 'employment_occupation'

# %%
# Create a function to encode dataset

def data_encoding(data):
    # Replace Binary Categories with 0 and 1
    data['sex'] = data['sex'].replace({'Male': 0, 'Female': 1})
    data['marital_status'] = data['marital_status'].replace({'Not Married': 0, 'Married': 1})
    data['rent_or_own'] = data['rent_or_own'].replace({'Rent': 0, 'Own': 1})

    # Replace Rank Order Categories starting with 0 to number of categories resepctively
    data['age_group'] = data['age_group'].replace({'18 - 34 Years': 0,
                                                               '35 - 44 Years': 1,
                                                               '45 - 54 Years': 2,
                                                               '55 - 64 Years': 3,
                                                               '65+ Years': 4
    })

    data['education'] = data['education'].replace({'< 12 Years': 0,
                                                               '12 Years': 1,
                                                               'Some College': 2,
                                                               'College Graduate': 3
    })

    data['income_poverty'] = data['income_poverty'].replace({'Below Poverty': 0,
                                                                         '<= $75,000, Above Poverty': 1,
                                                                         '> $75,000': 2
    })

    data['employment_status'] = data['employment_status'].replace({'Not in Labor Force': 0, 
                                                                               'Unemployed': 1,
                                                                               'Employed': 2
    })

    data['census_msa'] = data['census_msa'].replace({'Non-MSA': 0,
                                                                 'MSA, Not Principle  City': 1,
                                                                 'MSA, Principle City': 2
    })

    # One Hot Encode categories that do not have rank order
    #from sklearn.preprocessing import OneHotEncoder

    # Define the columns to be one hot encoded
    columns_to_encode = ['race', 'hhs_geo_region', 'employment_industry', 'employment_occupation']

    # Create an instance of the OneHotEncoder
    encoder = OneHotEncoder(sparse=False)

    # Fit and transform the selected columns
    encoded_columns = encoder.fit_transform(data[columns_to_encode])

    # Create a dataframe with the encoded columns
    encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names(columns_to_encode))

    # Set index back to DataFrame
    encoded_df.index = data.index
    
    # Concatenate the encoded dataframe with the original dataframe
    data_encoded = pd.concat([data, encoded_df], axis=1)
    
    # Drop the original columns that were encoded
    data_encoded.drop(columns_to_encode, axis=1, inplace=True)
    
    return data_encoded

# %%
# Use function
train_data_encoded = data_encoding(train_data)

train_data_encoded.head()
# Out:
#                h1n1_concern  ...  employment_occupation_nan
# respondent_id                ...
# 0                       1.0  ...                        1.0
# 1                       3.0  ...                        0.0
# 2                       1.0  ...                        0.0
# 3                       1.0  ...                        1.0
# 4                       2.0  ...                        0.0
#
# [5 rows x 93 columns]

# %% [markdown]
# ## Train/Validate H1N1 Vax with XGBoost

# %%
# Split Data into Train/Test (75%/25%)
X = train_data_encoded.drop(columns=['h1n1_vaccine','seasonal_vaccine'], axis=1)
y = train_data_encoded[['h1n1_vaccine']]

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    shuffle=True,
                                                    stratify=y,
                                                    random_state=1)

# %%
# Create XGB Model for H1N1 
xgb_h1n1 = xgb.XGBClassifier(colsample_bytree=0.6, 
                             learning_rate=0.01,
                             max_depth=5,
                             n_estimators=1000,
                             subsample=0.3)

# Fit the model on the entire training set
xgb_h1n1.fit(X_train, y_train)

# Predict probabilities for the TRAIN set
y_pred_proba_train_h1n1 = xgb_h1n1.predict_proba(X_train)

# Predict probabilities for the TEST set
y_pred_proba_test_h1n1 = xgb_h1n1.predict_proba(X_test)

# Predict scores for TEST set
y_preds_test_h1n1 = xgb_h1n1.predict(X_test)

# %%
# Create helper function to plot confusion matrix
def conf_matrix_plot(model, x_data, y_data):
    '''
    Accepts as argument model object, X data (test or validate), and y data (test or validate). 
    Returns a plot of confusion matrix for predictions on y data.
    ''' 
    model_pred = model.predict(x_data)
    cm = confusion_matrix(y_data, model_pred, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=model.classes_)
  
    disp.plot()
    plt.show()

# %%
# Display Confusion Matrix
conf_matrix_plot(xgb_h1n1, X_test, y_test)

# %%
# Classification Report (H1N1)
print(classification_report(y_test, y_preds_test_h1n1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      5258
#            1       0.75      0.52      0.61      1419
#
#     accuracy                           0.86      6677
#    macro avg       0.81      0.74      0.76      6677
# weighted avg       0.85      0.86      0.85      6677

# %%
# Calculate ROC AUC score for XGB
roc_auc_train_xgb_h1n1 = roc_auc_score(y_train, y_pred_proba_train_h1n1[:,1])
roc_auc_test_xgb_h1n1 = roc_auc_score(y_test, y_pred_proba_test_h1n1[:,1])

# Print ROC AUC scores
print(f'AUROC XGB H1n1 Train: {roc_auc_train_xgb_h1n1}'
      f'\nAUROC XGB H1n1 Test: {roc_auc_test_xgb_h1n1}'
)
# Out:
# AUROC XGB H1n1 Train: 0.9020944726163495
# AUROC XGB H1n1 Test: 0.8784268061205972

# %%
# Function to draw ROC curve and print score

def draw_roc_curve(test, pred_proba):
    # Generate ROC curve values: fpr, tpr, thresholds
    fpr, tpr, thresholds = roc_curve(test, pred_proba)

    # Plot ROC curve
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.show()
    
    return roc_auc_score(test, pred_proba)

# %%
# H1N1 Test
draw_roc_curve(y_test, y_pred_proba_test_h1n1[:,1])
# Out:
# 0.8784268061205972

# %% [markdown]
# ### Looks good so far as hyperparameters are good for H1N1. Try Seasonal

# %% [markdown]
# ## Create base model for seasonal (se) vax

# %%
# Split Data into Train/Test (75%/25%)
X_se = train_data_encoded.drop(columns=['h1n1_vaccine', 'seasonal_vaccine'], axis=1)
y_se = train_data_encoded[['seasonal_vaccine']]

X_train_se, X_test_se, y_train_se, y_test_se = train_test_split(X_se, y_se, 
                                                    test_size=0.25, 
                                                    shuffle=True,
                                                    stratify=y,
                                                    random_state=1)

# %%
# Create XGB Model for Seasonal
xgb_se = xgb.XGBClassifier(colsample_bytree=0.6, 
                           learning_rate=0.01,
                           max_depth=4,
                           n_estimators=1000,
                           subsample=0.3)

# Fit the model on the entire training set
xgb_se.fit(X_train_se, y_train_se)

# Predict probabilities for the TRAIN set
y_pred_proba_train_se = xgb_se.predict_proba(X_train_se)

# Predict probabilities for the TEST set
y_pred_proba_test_se = xgb_se.predict_proba(X_test_se)

# Predict scores for TEST set
y_preds_test_se = xgb_se.predict(X_test_se)

# %%
# Display Confusion Matrix
conf_matrix_plot(xgb_se, X_test_se, y_test_se)

# %%
# Classification Report (Seasonal)
print(classification_report(y_test_se, y_preds_test_se))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81      3524
#            1       0.80      0.76      0.78      3153
#
#     accuracy                           0.80      6677
#    macro avg       0.80      0.80      0.80      6677
# weighted avg       0.80      0.80      0.80      6677

# %%
# Seasonal Test
draw_roc_curve(y_test_se, y_pred_proba_test_se[:,1])
# Out:
# 0.8727496073321519

# %%
# Calculate ROC AUC score for XGB
roc_auc_train_xgb_se = roc_auc_score(y_train_se, y_pred_proba_train_se[:,1])
roc_auc_test_xgb_se = roc_auc_score(y_test_se, y_pred_proba_test_se[:,1])

# Print ROC AUC scores
print(f'AUROC XGB Seasonal Train: {roc_auc_train_xgb_se}'
      f'\nAUROC XGB Seasonal Test: {roc_auc_test_xgb_se}'
)
# Out:
# AUROC XGB Seasonal Train: 0.8768375160891415
# AUROC XGB Seasonal Test: 0.8727496073321519

# %% [markdown]
# ## Bayesian Optimization via Optuna

# %%
# !pip install optuna

import optuna
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting optuna
#   Downloading optuna-3.2.0-py3-none-any.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 38.5 MB/s eta 0:00:00
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from optuna) (1.8.1)
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.10.0-py3-none-any.whl (29 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from optuna) (1.23.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from optuna) (21.3)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from optuna) (1.4.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from optuna) (4.64.0)
# Requirement already satisfied: PyYAML in /usr/lib/python3/dist-packages (from optuna) (5.3.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.8/dist-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from alembic>=1.5.0->optuna) (4.12.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from alembic>=1.5.0->optuna) (5.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from sqlalchemy>=1.3.0->optuna) (1.1.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->alembic>=1.5.0->optuna) (3.8.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.8/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Installing collected packages: colorlog, cmaes, optuna
#   WARNING: The script optuna is installed in '/home/repl/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed cmaes-0.10.0 colorlog-6.7.0 optuna-3.2.0
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %% [markdown]
# ## Optuna with H1N1

# %%
# From https://www.datasnips.com/293/optimizing-xgboost-hyperparameters-with-optuna/
# Step 1: Define the objective function for Optuna to minimize
def objective_h1n1(trial):
    # Define the hyperparameters to tune
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'tree_method': 'hist',
        'max_depth': trial.suggest_int('max_depth', 2, 10),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
        'subsample': trial.suggest_uniform('subsample', 0.1, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.1, 1.0),
        'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1),
    }
    
    # Train an XGBoost model with the current hyperparameters
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dvalid = xgb.DMatrix(X_test, label=y_test)
    model = xgb.train(params, dtrain, num_boost_round=1000, 
                      evals=[(dvalid, 'validation')], early_stopping_rounds=20, verbose_eval=False)
    
    # Evaluate the model on the validation set and return the score
    y_pred = model.predict(dvalid)
    return roc_auc_score(y_test, y_pred)

# %%
# Step 2: Create an Optuna study object and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective_h1n1, n_trials=100)
# Out:
# [I 2023-07-21 21:24:19,157] A new study created in memory with name: no-name-efa066bd-1665-45cf-991d-8e2ddb0c835e
# [I 2023-07-21 21:24:20,744] Trial 0 finished with value: 0.8589802149870086 and parameters: {'max_depth': 4, 'learning_rate': 0.000342987582854932, 'subsample': 0.24059871518912776, 'colsample_bytree': 0.36690598130850927, 'min_child_weight': 0.0002755107299292709}. Best is trial 0 with value: 0.8589802149870086.
# [I 2023-07-21 21:24:23,450] Trial 1 finished with value: 0.8756151571175412 and parameters: {'max_depth': 6, 'learning_rate': 0.04316387821896661, 'subsample': 0.6955910399797004, 'colsample_bytree': 0.8046167729395896, 'min_child_weight': 0.03203620530931276}. Best is trial 1 with value: 0.8756151571175412.
# [I 2023-07-21 21:24:24,951] Trial 2 finished with value: 0.8553744473671583 and parameters: {'max_depth': 4, 'learning_rate': 0.0001108859831290457, 'subsample': 0.4348457556752271, 'colsample_bytree': 0.9259335274976217, 'min_child_weight': 0.1530919834470196}. Best is trial 1 with value: 0.8756151571175412.
# [I 2023-07-21 21:24:26,159] Trial 3 finished with value: 0.8654980859395838 and parameters: {'max_depth': 6, 'learning_rate': 0.0001833333396495846, 'subsample': 0.5483493440659616, 'colsample_bytree': 0.7699915939739103, 'min_child_weight': 0.0029729187952460463}. Best is trial 1 with value: 0.8756151571175412.
# [I 2023-07-21 21:24:27,120] Trial 4 finished with value: 0.8680847011607669 and parameters: {'max_depth': 8, 'learning_rate': 0.00011873708898014209, 'subsample': 0.9390472555776808, 'colsample_bytree': 0.4563884706114637, 'min_child_weight': 0.123035337799014}. Best is trial 1 with value: 0.8756151571175412.
# [I 2023-07-21 21:24:32,484] Trial 5 finished with value: 0.8753889170795414 and parameters: {'max_depth': 9, 'learning_rate': 0.010391556907755315, 'subsample': 0.7118992573229282, 'colsample_bytree': 0.6960112841742608, 'min_child_weight': 0.012442678790332567}. Best is trial 1 with value: 0.8756151571175412.
# [I 2023-07-21 21:24
. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:27:03,062] Trial 32 finished with value: 0.8766548158703633 and parameters: {'max_depth': 4, 'learning_rate': 0.013722096841083211, 'subsample': 0.27259136711810955, 'colsample_bytree': 0.8072308520101104, 'min_child_weight': 0.34153663395195555}. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:27:13,311] Trial 33 finished with value: 0.8766569603257 and parameters: {'max_depth': 4, 'learning_rate': 0.012373658737365505, 'subsample': 0.26136555772393416, 'colsample_bytree': 0.7893686230626481, 'min_child_weight': 0.9671364712906619}. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:27:19,128] Trial 34 finished with value: 0.8765237360379203 and parameters: {'max_depth': 6, 'learning_rate': 0.014915300681285482, 'subsample': 0.19744046903995888, 'colsample_bytree': 0.7977932314659757, 'min_child_weight': 0.7895742278156245}. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:27:19,749] Trial 35 finished with value: 0.8407580408363268 and parameters: {'max_depth': 3, 'learning_rate': 0.004402934053526564, 'subsample': 0.2591065505061214, 'colsample_bytree': 0.9181877448183475, 'min_child_weight': 0.20278595838857502}. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:27:35,009] Trial 36 finished with value: 0.8771153376538748 and parameters: {'max_depth': 4, 'learning_rate': 0.009130641972495617, 'subsample': 0.39947374067812286, 'colsample_bytree': 0.7206625078342992, 'min_child_weight': 0.1407601648382612}. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:27:35,528] Trial 37 finished with value: 0.8413641175258024 and parameters: {'max_depth': 2, 'learning_rate': 0.008753348592240773, 'subsample': 0.39255478288562656, 'colsample_bytree': 0.7025531494147398, 'min_child_weight': 0.11748935660070037}. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:27:36,699] Trial 38 finished with value: 0.8589296192439133 and parameters: {'max_depth': 4, 'learning_rate': 0.0022540657418146336, 'subsample': 0.44442990995540915, 'colsample_bytree': 0.7295783322087381, 'min_child_weight': 0.13064410009818578}. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:27:42,453] Trial 39 finished with value: 0.8770776756570277 and parameters: {'max_depth': 6, 'learning_rate': 0.019468943329790375, 'subsample': 0.5403340272210283, 'colsample_bytree': 0.9411133422027748, 'min_child_weight': 0.029780921265767885}. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:27:46,919] Trial 40 finished with value: 0.8768464765660623 and parameters: {'max_depth': 6, 'learning_rate': 0.01871216333735885, 'subsample': 0.4598145357065023, 'colsample_bytree': 0.8038015780613739, 'min_child_weight': 0.029417030741029332}. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:27:48,836] Trial 41 finished with value: 0.8689580305965526 and parameters: {'max_depth': 6, 'learning_rate': 0.009283613828014133, 'subsample': 0.4651756288334986, 'colsample_bytree': 0.8179213693256338, 'min_child_weight': 0.02982949212713224}. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:27:53,035] Trial 42 finished with value: 0.8759412483571462 and parameters: {'max_depth': 7, 'learning_rate': 0.018392925090572967, 'subsample': 0.386909487357244, 'colsample_bytree': 0.7420923985961313, 'min_child_weight': 0.00714621822629555}. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:27:59,460] Trial 43 finished with value: 0.8757451647223158 and parameters: {'max_depth': 6, 'learning_rate': 0.011898100371134888, 'subsample': 0.5356101500344436, 'colsample_bytree': 0.6612634842324698, 'min_child_weight': 0.028644448049816144}. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:28:06,167] Trial 44 finished with value: 0.8767903186419379 and parameters: {'max_depth': 6, 'learning_rate': 0.01623385412874703, 'subsample': 0.4576104687666717, 'colsample_bytree': 0.765167896120199, 'min_child_weight': 0.14248302552819714}. Best is trial 28 with value: 0.8775009375290674.
# [I 2023-07-21 21:28
. Best is trial 53 with value: 0.878163574228043.
# [I 2023-07-21 21:32:22,530] Trial 96 finished with value: 0.8776446160366123 and parameters: {'max_depth': 5, 'learning_rate': 0.010388129819669476, 'subsample': 0.3043366374751472, 'colsample_bytree': 0.8875003781506923, 'min_child_weight': 0.08017362946581318}. Best is trial 53 with value: 0.878163574228043.
# [I 2023-07-21 21:32:30,654] Trial 97 finished with value: 0.8772176013677336 and parameters: {'max_depth': 6, 'learning_rate': 0.01033740486579629, 'subsample': 0.36064392658774513, 'colsample_bytree': 0.920933662930668, 'min_child_weight': 0.1302236534359876}. Best is trial 53 with value: 0.878163574228043.
# [I 2023-07-21 21:32:32,112] Trial 98 finished with value: 0.8578959917717248 and parameters: {'max_depth': 4, 'learning_rate': 0.007441525452197351, 'subsample': 0.30874411951352454, 'colsample_bytree': 0.8940564137024297, 'min_child_weight': 0.08866299193466574}. Best is trial 53 with value: 0.878163574228043.
# [I 2023-07-21 21:32:40,737] Trial 99 finished with value: 0.8771282043858938 and parameters: {'max_depth': 5, 'learning_rate': 0.013386188992296677, 'subsample': 0.34717409218894985, 'colsample_bytree': 0.8739024520785155, 'min_child_weight': 0.3217813759207335}. Best is trial 53 with value: 0.878163574228043.

# %%
# Step 3: Print the best hyperparameters and score found by Optuna
print(f'Best score: {study.best_value:.5f}')
print('Best parameters:')
for key, value in study.best_params.items():
    print(f'    {key}: {value}')
# Out:
# Best score: 0.87816
# Best parameters:
#     max_depth: 5
#     learning_rate: 0.0315181778773347
#     subsample: 0.3202202580083733
#     colsample_bytree: 0.8848537431680721
#     min_child_weight: 0.18075727071480643

# %% [markdown]
# ## Optuna with Seasonal

# %%
# Step 1: Define the objective function for Optuna to minimize
def objective_se(trial):
    # Define the hyperparameters to tune
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'tree_method': 'hist',
        'max_depth': trial.suggest_int('max_depth', 2, 10),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
        'subsample': trial.suggest_uniform('subsample', 0.1, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.1, 1.0),
        'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1),
    }
    
    # Train an XGBoost model with the current hyperparameters
    dtrain = xgb.DMatrix(X_train_se, label=y_train_se)
    dvalid = xgb.DMatrix(X_test_se, label=y_test_se)
    model = xgb.train(params, dtrain, num_boost_round=1000, 
                      evals=[(dvalid, 'validation')], early_stopping_rounds=20, verbose_eval=False)
    
    # Evaluate the model on the validation set and return the score
    y_pred = model.predict(dvalid)
    return roc_auc_score(y_test_se, y_pred)

# %%
# Step 2: Create an Optuna study object and optimize the objective function
study_se = optuna.create_study(direction='maximize')
study_se.optimize(objective_se, n_trials=100)
# Out:
# [I 2023-07-21 21:38:10,767] A new study created in memory with name: no-name-dfa1eaf4-75cd-4071-98e2-5398138bb899
# [I 2023-07-21 21:38:12,833] Trial 0 finished with value: 0.8588706483888467 and parameters: {'max_depth': 8, 'learning_rate': 0.0002741885095875314, 'subsample': 0.4711851638993163, 'colsample_bytree': 0.35094900657349337, 'min_child_weight': 0.0025076556685375367}. Best is trial 0 with value: 0.8588706483888467.
# [I 2023-07-21 21:38:13,745] Trial 1 finished with value: 0.8411505104952025 and parameters: {'max_depth': 2, 'learning_rate': 0.01309393460714148, 'subsample': 0.307717012868085, 'colsample_bytree': 0.16083054123743362, 'min_child_weight': 0.4256307349168694}. Best is trial 0 with value: 0.8588706483888467.
# [I 2023-07-21 21:38:15,657] Trial 2 finished with value: 0.8653115080929356 and parameters: {'max_depth': 9, 'learning_rate': 0.0019869331835188028, 'subsample': 0.8837269022254999, 'colsample_bytree': 0.4957813901980811, 'min_child_weight': 0.4464359520924987}. Best is trial 2 with value: 0.8653115080929356.
# [I 2023-07-21 21:38:31,446] Trial 3 finished with value: 0.8721555205877471 and parameters: {'max_depth': 5, 'learning_rate': 0.008829113369373438, 'subsample': 0.8512446698961961, 'colsample_bytree': 0.9775863075591394, 'min_child_weight': 7.973327379620888e-05}. Best is trial 3 with value: 0.8721555205877471.
# [I 2023-07-21 21:38:32,446] Trial 4 finished with value: 0.8394601847581876 and parameters: {'max_depth': 3, 'learning_rate': 0.003345150725850516, 'subsample': 0.15712512136503068, 'colsample_bytree': 0.16718872438109694, 'min_child_weight': 0.06117164176488351}. Best is trial 3 with value: 0.8721555205877471.
# [I 2023-07-21 21:38:36,898] Trial 5 finished with value: 0.8727592372793799 and parameters: {'max_depth': 7, 'learning_rate': 0.02852784062589677, 'subsample': 0.6932374722221735, 'colsample_bytree': 0.5417504055508678, 'min_child_weight': 0.27324709710435097}. Best is trial 5 with value: 0.8727592372793799.
# [I 2023-07-21 21:38:37,540] Trial 6 finished with value: 0.845678655680967 and parameters: {'max_depth': 3, 'learning_rate': 0.0005589491411812848, 'subsample': 0.8590553561153114, 'colsample_bytree': 0.4882841640295452, 'min_child_weight': 0.0006423415846213028}. Best is trial 5 with value: 0.8727592372793799.
# [I 2023-07-21 21:38:43,099] Trial 7 finished with value: 0.862617957853591 and parameters: {'max_depth': 4, 'learning_rate': 0.010332743056392368, 'subsample': 0.6824711614737398, 'colsample_bytree': 0.19728855852375243, 'min_child_weight': 0.016260012019344947}. Best is trial 5 with value: 0.8727592372793799.
# [I 2023-07-21 21:38:48,834] Trial 8 finished with value: 0.8726186580497538 and parameters: {'max_depth': 6, 'learning_rate': 0.018946114063879665, 'subsample': 0.5353777658487338, 'colsample_bytree': 0.6885754764895207, 'min_child_weight': 0.3237400115766679}. Best is trial 5 with value: 0.8727592372793799.
# [I 2023-07-21 21:38:50,023] Trial 9 finished with value: 0.855137828844698 and parameters: {'max_depth': 8, 'learning_rate': 0.00010999530022852696, 'subsample': 0.90646590373789, 'colsample_bytree': 0.29007109638740697, 'min_child_weight': 0.07702320405024213}. Best is trial 5 with value: 0.8727592372793799.
# [I 2023-07-21 21:38:52,053] Trial 10 finished with value: 0.8715607138472881 and parameters: {'max_depth': 7, 'learning_rate': 0.09130190527927308, 'subsample': 0.7200346298914929, 'colsample_bytree': 0.6856575154055925, 'min_child_weight': 1.5728001164185036e-05}. Best is trial 5 with value: 0.8727592372793799.
# [I 2023-07-21 21:38:54,439] Trial 11 finished with value: 0.8712015708153921 and parameters: {'max_depth': 6, 'learning_rate': 0.05698279008915664, 'subsample': 0.5565302103271403, 'colsample_bytree': 0.6808963689889255, 'min_child_weight': 0.41096541916705287}. Best is trial 5 with value: 0.8727592372793799.
# [I 2023-07-21 21:38:58,104] Trial 12 finished with value: 0.8728985565159103 and parameters: {'max_depth': 6, 'learning_rate': 0.03657043732092856, 'subsample': 0.5146392715915787, 'colsample_bytree': 0.690105729530186, 'min_child_weight': 0.03023806517011929}. Best is trial 12 with value: 0.8728985565159103.
# [I 2023-07-21 21:39:02,503] Trial 13 finished with value: 0.8703382055466337 and parameters: {'max_depth': 10, 'learning_rate': 0.033011038925844255, 'subsample': 0.6700007338890787, 'colsample_bytree': 0.589380723557191, 'min_child_weight': 0.018595674998409736}. Best is trial 12 with value: 0.8728985565159103.
# [I 2023-07-21 21:39:03,428] Trial 14 finished with value: 0.8664590918041769 and parameters: {'max_depth': 7, 'learning_rate': 0.09142482359518653, 'subsample': 0.4327604997453363, 'colsample_bytree': 0.8181434867969672, 'min_child_weight': 0.03176525433203776}. Best is trial 12 with value: 0.8728985565159103.
# [I 2023-07-21 21:39:11,533] Trial 15 finished with value: 0.874228389228427 and parameters: {'max_depth': 5, 'learning_rate': 0.032865987523625004, 'subsample': 0.9886146091370257, 'colsample_bytree': 0.42522056369771866, 'min_child_weight': 0.002631334761070745}. Best is trial 15 with value: 0.874228389228427.
# [I 2023-07-21 21:39:15,319] Trial 16 finished with value: 0.8739267108816242 and parameters: {'max_depth': 5, 'learning_rate': 0.046818711046594914, 'subsample': 0.9860741053918216, 'colsample_bytree': 0.3712762877272432, 'min_child_weight': 0.004149097563783965}. Best is trial 15 with value: 0.874228389228427.
# [I 2023-07-21 21:39:23,360] Trial 17 finished with value: 0.8740908699820324 and parameters: {'max_depth': 4, 'learning_rate': 0.047368014662351896, 'subsample': 0.9817569064166989, 'colsample_bytree': 0.3739358235969781, 'min_child_weight': 0.0032716684267122373}. Best is trial 15 with value: 0.874228389228427.
# [I 2023-07-21 21:39:38,102] Trial 18 finished with value: 0.8710365567196691 and parameters: {'max_depth': 4, 'learning_rate': 0.007218043344090839, 'subsample': 0.9693041921463253, 'colsample_bytree': 0.4144354037307381, 'min_child_weight': 0.0005752864397141512}. Best is trial 15 with value: 0.874228389228427.
# [I 2023-07-21 21:39:52,261] Trial 19 finished with value: 0.8698729530962171 and parameters: {'max_depth': 2, 'learning_rate': 0.019382118492859715, 'subsample': 0.8021312478834677, 'colsample_bytree': 0.2619050818873767, 'min_child_weight': 0.0053950897895031925}. Best is trial 15 with value: 0.874228389228427.
# [I 2023-07-21 21:39:57,035] Trial 20 finished with value: 0.8738817561279766 and parameters: {'max_depth': 4, 'learning_rate': 0.06303363407256445, 'subsample': 0.964031611354961, 'colsample_bytree': 0.41459959908171024, 'min_child_weight': 0.001402336685832956}. Best is trial 15 with value: 0.874228389228427.
# [I 2023-07-21 21:40:02,442] Trial 21 finished with value: 0.8741888794449407 and parameters: {'max_depth': 5, 'learning_rate': 0.04254272589386214, 'subsample': 0.9913735732298748, 'colsample_bytree': 0.37017722979257994, 'min_child_weight': 0.0065437119902800565}. Best is trial 15 with value: 0.874228389228427.
# [I 2023-07-21 21:40:05,027] Trial 22 finished with value: 0.8731298552483933 and parameters: {'max_depth': 5, 'learning_rate': 0.09972589020016702, 'subsample': 0.981645558946039, 'colsample_bytree': 0.2947432139207603, 'min_child_weight': 0.005837291501014365}. Best is trial 15 with value: 0.874228389228427.
# [I 2023-07-21 21:40:14,948] Trial 23 finished with value: 0.8729895460172878 and parameters: {'max_depth': 3, 'learning_rate': 0.02646320303519652, 'subsample': 0.8077758085969685, 'colsample_bytree': 0.4399926302085068, 'min_child_weight': 0.00931212900021866}. Best is trial 15 with value: 0.874228389228427.
# [I 2023-07-21 21:40:19,655] Trial 24 finished with value: 0.8743614984989883 and parameters: {'max_depth': 5, 'learning_rate': 0.049227476205954655, 'subsample': 0.9169593918402137, 'colsample_bytree': 0.3550156277376698, 'min_child_weight': 0.0013652264149518003}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:40:30,762] Trial 25 finished with value: 0.8742674490143794 and parameters: {'max_depth': 5, 'learning_rate': 0.02349367561332112, 'subsample': 0.9130865937109235, 'colsample_bytree': 0.23806289241374723, 'min_child_weight': 0.0012471214485816433}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:40:32,128] Trial 26 finished with value: 0.8377414191770229 and parameters: {'max_depth': 6, 'learning_rate': 0.017103785263811094, 'subsample': 0.7790561397894687, 'colsample_bytree': 0.12445811735631127, 'min_child_weight': 0.0005844600802657701}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:40:33,054] Trial 27 finished with value: 0.852533603115855 and parameters: {'max_depth': 5, 'learning_rate': 0.0064494348748354345, 'subsample': 0.9215984192675359, 'colsample_bytree': 0.23922882259125683, 'min_child_weight': 0.001282577502723549}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:40:34,205] Trial 28 finished with value: 0.8384802251283663 and parameters: {'max_depth': 6, 'learning_rate': 0.028112971165154325, 'subsample': 0.901565847754355, 'colsample_bytree': 0.10818324515047101, 'min_child_weight': 0.00040285208431592917}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:40:45,003] Trial 29 finished with value: 0.8733794688805105 and parameters: {'max_depth': 8, 'learning_rate': 0.015578523166009968, 'subsample': 0.832305739158029, 'colsample_bytree': 0.32479436321941957, 'min_child_weight': 0.0022216938649316006}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:40:52,131] Trial 30 finished with value: 0.8727475373434953 and parameters: {'max_depth': 7, 'learning_rate': 0.02281996996160721, 'subsample': 0.7533417165986054, 'colsample_bytree': 0.2454452895821067, 'min_child_weight': 0.00016543244282560097}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:40:55,115] Trial 31 finished with value: 0.8733629989707656 and parameters: {'max_depth': 5, 'learning_rate': 0.05066345942302323, 'subsample': 0.929347141230417, 'colsample_bytree': 0.3516344464340078, 'min_child_weight': 0.0021360254586573067}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:41:01,506] Trial 32 finished with value: 0.8739489407598048 and parameters: {'max_depth': 5, 'learning_rate': 0.03833177915016164, 'subsample': 0.9977109590526331, 'colsample_bytree': 0.3240851634753745, 'min_child_weight': 0.006391211480767858}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:41:15,710] Trial 33 finished with value: 0.8722998797966587 and parameters: {'max_depth': 4, 'learning_rate': 0.013343668231501899, 'subsample': 0.8815342210289961, 'colsample_bytree': 0.20548165447910982, 'min_child_weight': 0.0013069405373751122}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:41:31,455] Trial 34 finished with value: 0.8734931382576023 and parameters: {'max_depth': 5, 'learning_rate': 0.011198397853498942, 'subsample': 0.9230184591925195, 'colsample_bytree': 0.29648008772683193, 'min_child_weight': 0.0028389810054785065}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:41:36,824] Trial 35 finished with value: 0.873098085422492 and parameters: {'max_depth': 3, 'learning_rate': 0.06691560121651206, 'subsample': 0.85968119545495, 'colsample_bytree': 0.3780355166907208, 'min_child_weight': 0.008863585234856797}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:41
. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:43:12,819] Trial 49 finished with value: 0.8470542081429393 and parameters: {'max_depth': 6, 'learning_rate': 0.0187875382318259, 'subsample': 0.9995071682418339, 'colsample_bytree': 0.18636163509185757, 'min_child_weight': 0.01566738083149501}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:43:16,525] Trial 50 finished with value: 0.8551027740367984 and parameters: {'max_depth': 4, 'learning_rate': 0.00220268570887927, 'subsample': 0.8631165083328345, 'colsample_bytree': 0.21716089398864968, 'min_child_weight': 0.0016234855707258499}. Best is trial 24 with value: 0.8743614984989883.
# [I 2023-07-21 21:43:23,623] Trial 51 finished with value: 0.8744550079865563 and parameters: {'max_depth': 4, 'learning_rate': 0.04508671215551158, 'subsample': 0.9644869733440361, 'colsample_bytree': 0.31088638986402517, 'min_child_weight': 0.004104143980086446}. Best is trial 51 with value: 0.8744550079865563.
# [I 2023-07-21 21:43:28,596] Trial 52 finished with value: 0.8746989966494984 and parameters: {'max_depth': 5, 'learning_rate': 0.03942431779882817, 'subsample': 0.9500787393666866, 'colsample_bytree': 0.2951610269498106, 'min_child_weight': 0.004801803542657761}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:43:32,751] Trial 53 finished with value: 0.8738889110887672 and parameters: {'max_depth': 5, 'learning_rate': 0.07828962198848138, 'subsample': 0.9507484160878726, 'colsample_bytree': 0.3196268815245376, 'min_child_weight': 0.0045668839148948785}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:43:37,018] Trial 54 finished with value: 0.8739502907524067 and parameters: {'max_depth': 6, 'learning_rate': 0.051527055608228955, 'subsample': 0.9574754173931613, 'colsample_bytree': 0.4068049911269438, 'min_child_weight': 0.007833792207486345}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:43:42,232] Trial 55 finished with value: 0.8705655443008172 and parameters: {'max_depth': 10, 'learning_rate': 0.03877889205500103, 'subsample': 0.9084514006027854, 'colsample_bytree': 0.35199048867863747, 'min_child_weight': 0.013796235682551485}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:43:45,521] Trial 56 finished with value: 0.8736493324016584 and parameters: {'max_depth': 5, 'learning_rate': 0.0807945286939752, 'subsample': 0.9687902689072379, 'colsample_bytree': 0.3042482290574222, 'min_child_weight': 0.00497791398698003}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:43:49,040] Trial 57 finished with value: 0.8727090175545837 and parameters: {'max_depth': 6, 'learning_rate': 0.05758534134223342, 'subsample': 0.9217123604746648, 'colsample_bytree': 0.27134511646490145, 'min_child_weight': 0.025085770815480614}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:43:56,235] Trial 58 finished with value: 0.8739597407006209 and parameters: {'max_depth': 5, 'learning_rate': 0.034307814695214586, 'subsample': 0.8935402398104458, 'colsample_bytree': 0.2458633279593009, 'min_child_weight': 0.00663604225724542}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:44:02,463] Trial 59 finished with value: 0.872606778114856 and parameters: {'max_depth': 4, 'learning_rate': 0.044276727106761664, 'subsample': 0.9724800144104079, 'colsample_bytree': 0.4956171130248776, 'min_child_weight': 0.0041975839756236985}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:44:13,660] Trial 60 finished with value: 0.8731375052064715 and parameters: {'max_depth': 3, 'learning_rate': 0.02950077580020543, 'subsample': 0.8191167452517821, 'colsample_bytree': 0.3845864433305297, 'min_child_weight': 0.042697887064180075}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:44:24,140] Trial 61 finished with value: 0.8738435513373388 and parameters: {'max_depth': 4, 'learning_rate': 0.023777649764412018, 'subsample': 0.8590399323123239, 'colsample_bytree': 0.2698141627936014, 'min_child_weight': 0.00211707344259268}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:44:28,115] Trial 62 finished with value: 0.8733358641194645 and parameters: {'max_depth': 4, 'learning_rate': 0.06313300570041147, 'subsample': 0.9415427469444383, 'colsample_bytree': 0.2974297987909157, 'min_child_weight': 0.002389546907404856}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:44:38,130] Trial 63 finished with value: 0.8744334081049235 and parameters: {'max_depth': 5, 'learning_rate': 0.02153715489822319, 'subsample': 0.9694747959447217, 'colsample_bytree': 0.33524464035091384, 'min_child_weight': 0.011608675679814667}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:44:44,441] Trial 64 finished with value: 0.8744630179426616 and parameters: {'max_depth': 5, 'learning_rate': 0.04145921089652207, 'subsample': 0.9695765323275956, 'colsample_bytree': 0.3466687510191917, 'min_child_weight': 0.010633000809405288}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:44:50,465] Trial 65 finished with value: 0.8742273092343453 and parameters: {'max_depth': 5, 'learning_rate': 0.03366658625398402, 'subsample': 0.9168173964292433, 'colsample_bytree': 0.3369621664144957, 'min_child_weight': 0.012952068667318732}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:45:02,407] Trial 66 finished with value: 0.874221639265417 and parameters: {'max_depth': 5, 'learning_rate': 0.019047373731370252, 'subsample': 0.96344098770878, 'colsample_bytree': 0.23094213183152004, 'min_child_weight': 0.022080861815439033}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:45:04,525] Trial 67 finished with value: 0.8733091342659443 and parameters: {'max_depth': 6, 'learning_rate': 0.09076904845971254, 'subsample': 0.9987435886614627, 'colsample_bytree': 0.3079041144861673, 'min_child_weight': 0.009710934021649586}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:45:14,865] Trial 68 finished with value: 0.8735356630245669 and parameters: {'max_depth': 5, 'learning_rate': 0.014027353493094528, 'subsample': 0.8966834993952281, 'colsample_bytree': 0.3564667073857103, 'min_child_weight': 0.018612626435611707}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:45:18,341] Trial 69 finished with value: 0.8722101952881299 and parameters: {'max_depth': 7, 'learning_rate': 0.051103119763921345, 'subsample': 0.9711652448995883, 'colsample_bytree': 0.19247331678001078, 'min_child_weight': 0.0033933201061648187}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:45:23,993] Trial 70 finished with value: 0.8735934427079339 and parameters: {'max_depth': 6, 'learning_rate': 0.027091294617227195, 'subsample': 0.9242534489573682, 'colsample_bytree': 0.42133526944859817, 'min_child_weight': 0.0059727625156207045}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:45:29,050] Trial 71 finished with value: 0.8737757367089628 and parameters: {'max_depth': 5, 'learning_rate': 0.03266343409835941, 'subsample': 0.870494232751099, 'colsample_bytree': 0.3423721607878284, 'min_child_weight': 0.012532257729137053}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:45:35,529] Trial 72 finished with value: 0.8741627795879678 and parameters: {'max_depth': 5, 'learning_rate': 0.03918294809713231, 'subsample': 0.9407702908443367, 'colsample_bytree': 0.3313518588180422, 'min_child_weight': 0.01188411295223387}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:45:39,517] Trial 73 finished with value: 0.8739687406513013 and parameters: {'max_depth': 5, 'learning_rate': 0.05899442290004708, 'subsample': 0.9184022294857834, 'colsample_bytree': 0.3153463932689803, 'min_child_weight': 0.0076374037112695945}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:45:47,831] Trial 74 finished with value: 0.8741586396106549 and parameters: {'max_depth': 6, 'learning_rate': 0.019783346826254877, 'subsample': 0.9725513506955145, 'colsample_bytree': 0.35961058278989566, 'min_child_weight': 0.016980723712945473}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:45:52,841] Trial 75 finished with value: 0.8736712922813181 and parameters: {'max_depth': 5, 'learning_rate': 0.04288418092424553, 'subsample': 0.8854904395986151, 'colsample_bytree': 0.3873498204361946, 'min_child_weight': 0.0040157830251268956}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:46:01,538] Trial 76 finished with value: 0.8739467807716415 and parameters: {'max_depth': 4, 'learning_rate': 0.03399280855756425, 'subsample': 0.9159071723019098, 'colsample_bytree': 0.25424226961196705, 'min_child_weight': 0.010470777183341464}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:46:13,824] Trial 77 finished with value: 0.8739400308086311 and parameters: {'max_depth': 5, 'learning_rate': 0.016659143150521735, 'subsample': 0.9425555780454321, 'colsample_bytree': 0.2948040204675019, 'min_child_weight': 0.0010793057436786053}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:46:21,432] Trial 78 finished with value: 0.8737040521017946 and parameters: {'max_depth': 6, 'learning_rate': 0.02633014924723032, 'subsample': 0.9786298065926939, 'colsample_bytree': 0.4003245393142732, 'min_child_weight': 0.04015268814236197}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:46:23,232] Trial 79 finished with value: 0.8694718702941509 and parameters: {'max_depth': 9, 'learning_rate': 0.07287344092911457, 'subsample': 0.8263353311744698, 'colsample_bytree': 0.33672861680543154, 'min_child_weight': 0.001640809246477233}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:46:27,517] Trial 80 finished with value: 0.8731524451246007 and parameters: {'max_depth': 4, 'learning_rate': 0.05592050138962497, 'subsample': 0.8790051162930702, 'colsample_bytree': 0.36536488325980765, 'min_child_weight': 0.005573566942738608}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:46:40,358] Trial 81 finished with value: 0.874158639610655 and parameters: {'max_depth': 5, 'learning_rate': 0.02185559574238993, 'subsample': 0.9554390934835009, 'colsample_bytree': 0.22339648566266285, 'min_child_weight': 0.022301975152515426}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:46:53,123] Trial 82 finished with value: 0.8743146087559441 and parameters: {'max_depth': 5, 'learning_rate': 0.01808753446024541, 'subsample': 0.9993980436164857, 'colsample_bytree': 0.2389563708398482, 'min_child_weight': 0.008263718632375282}. Best is trial 52 with value: 0.8746989966494984.
# [I 2023-07-21 21:47:00,260] Trial 83 finished with value: 0.8748379108882485 and parameters: {'max_depth': 5, 'learning_rate': 0.03217156742354802, 'subsample': 0.9882133490122514, 'colsample_bytree': 0.2723823854292983, 'min_child_weight': 0.0032118738505435636}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:47:07,951] Trial 84 finished with value: 0.8742152943001872 and parameters: {'max_depth': 4, 'learning_rate': 0.045006550688367127, 'subsample': 0.9710425620428376, 'colsample_bytree': 0.2701448361743691, 'min_child_weight': 0.0026343279153734555}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:47:08,999] Trial 85 finished with value: 0.8418599316075748 and parameters: {'max_depth': 5, 'learning_rate': 0.012340429526241323, 'subsample': 0.9414627876867994, 'colsample_bytree': 0.14951895019416991, 'min_child_weight': 0.003484118966875331}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:47:15,527] Trial 86 finished with value: 0.8740420902493454 and parameters: {'max_depth': 6, 'learning_rate': 0.02763142176132901, 'subsample': 0.990879643216544, 'colsample_bytree': 0.24139849949144576, 'min_child_weight': 0.007846984429347769}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:47:23,164] Trial 87 finished with value: 0.8734588034457571 and parameters: {'max_depth': 5, 'learning_rate': 0.037924511049016105, 'subsample': 0.9961917024587522, 'colsample_bytree': 0.20398925334042656, 'min_child_weight': 0.0018047553705632373}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:47:32,736] Trial 88 finished with value: 0.8741656595721856 and parameters: {'max_depth': 5, 'learning_rate': 0.02173301376784175, 'subsample': 0.9538786303997977, 'colsample_bytree': 0.2803861468184706, 'min_child_weight': 0.0012364902168079054}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:47:47,150] Trial 89 finished with value: 0.8735368780179085 and parameters: {'max_depth': 4, 'learning_rate': 0.014876805583714325, 'subsample': 0.9799318288498707, 'colsample_bytree': 0.31121369660457643, 'min_child_weight': 0.0007143111690224794}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:47:48,292] Trial 90 finished with value: 0.8560086190727674 and parameters: {'max_depth': 6, 'learning_rate': 0.010127700246064424, 'subsample': 0.8973165288375953, 'colsample_bytree': 0.25832163166028915, 'min_child_weight': 0.0028267219124641823}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:47:54,900] Trial 91 finished with value: 0.874040470258223 and parameters: {'max_depth': 5, 'learning_rate': 0.03381512712157091, 'subsample': 0.9210882864422475, 'colsample_bytree': 0.331466811328766, 'min_child_weight': 0.01246225829439932}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:47:59,640] Trial 92 finished with value: 0.8746547168921515 and parameters: {'max_depth': 5, 'learning_rate': 0.04718032713466428, 'subsample': 0.9317643798171318, 'colsample_bytree': 0.2925318905421411, 'min_child_weight': 0.005131127465025623}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:48:05,343] Trial 93 finished with value: 0.8746332070100256 and parameters: {'max_depth': 5, 'learning_rate': 0.044228826090176115, 'subsample': 0.935273714449809, 'colsample_bytree': 0.2921478586750914, 'min_child_weight': 0.004587719360561323}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:48:11,341] Trial 94 finished with value: 0.8742056643529594 and parameters: {'max_depth': 5, 'learning_rate': 0.04505941396889286, 'subsample': 0.8489975581636393, 'colsample_bytree': 0.29248178527881796, 'min_child_weight': 0.0047774090586061415}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:48:15,159] Trial 95 finished with value: 0.8733456740657063 and parameters: {'max_depth': 6, 'learning_rate': 0.05360736322384616, 'subsample': 0.9340091148522409, 'colsample_bytree': 0.23522640090245744, 'min_child_weight': 0.006894901025253835}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:48:19,142] Trial 96 finished with value: 0.8733102592597792 and parameters: {'max_depth': 4, 'learning_rate': 0.067348071252283, 'subsample': 0.9027807586007003, 'colsample_bytree': 0.28450490123681454, 'min_child_weight': 0.0037259061203303787}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:48:21,405] Trial 97 finished with value: 0.8520187159374366 and parameters: {'max_depth': 5, 'learning_rate': 0.03945821023592453, 'subsample': 0.951899334099813, 'colsample_bytree': 0.18258023363495474, 'min_child_weight': 0.005361471253576661}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:48:32,603] Trial 98 finished with value: 0.8740712500895496 and parameters: {'max_depth': 4, 'learning_rate': 0.029257505752738337, 'subsample': 0.8826650124606307, 'colsample_bytree': 0.21788581804032758, 'min_child_weight': 0.009472879370031514}. Best is trial 83 with value: 0.8748379108882485.
# [I 2023-07-21 21:48:36,943] Trial 99 finished with value: 0.873728441968138 and parameters: {'max_depth': 5, 'learning_rate': 0.0493316694794558, 'subsample': 0.9801406841630066, 'colsample_bytree': 0.26409081010606755, 'min_child_weight': 0.002423506918935681}. Best is trial 83 with value: 0.8748379108882485.

# %%
# Step 3: Print the best hyperparameters and score found by Optuna
print(f'Best score: {study_se.best_value:.5f}')
print('Best parameters:')
for key, value in study_se.best_params.items():
    print(f'    {key}: {value}')
# Out:
# Best score: 0.87484
# Best parameters:
#     max_depth: 5
#     learning_rate: 0.03217156742354802
#     subsample: 0.9882133490122514
#     colsample_bytree: 0.2723823854292983
#     min_child_weight: 0.0032118738505435636

# %% [markdown]
# ## Fit Respective Models with Optuna Hyperparameters

# %%
# H1N1 w/ Optuna
xgb_h1n1_opt = xgb.XGBClassifier(max_depth=5,
                                 learning_rate=0.0315181778773347,
                                 subsample=0.3202202580083733,
                                 colsample_bytree=0.8848537431680721,
                                 min_child_weight=0.18075727071480643,
                                 n_estimators=1000)

# Fit the model on the entire training set
xgb_h1n1_opt.fit(X_train, y_train)

# Predict probabilities for the TRAIN set
y_pred_proba_train_h1n1_opt = xgb_h1n1_opt.predict_proba(X_train)

# Predict probabilities for the TEST set
y_pred_proba_test_h1n1_opt = xgb_h1n1_opt.predict_proba(X_test)

# Predict scores for TEST set
y_preds_test_h1n1_opt = xgb_h1n1_opt.predict(X_test)

# %%
# Display Confusion Matrix
conf_matrix_plot(xgb_h1n1_opt, X_test, y_test)

# Classification Report (Seasonal)
print(classification_report(y_test, y_preds_test_h1n1_opt))

# Seasonal Test
draw_roc_curve(y_test, y_pred_proba_test_h1n1_opt[:,1])

# Calculate ROC AUC score for XGB
roc_auc_train_xgb_h1n1_opt = roc_auc_score(y_train, y_pred_proba_train_h1n1_opt[:,1])
roc_auc_test_xgb_h1n1_opt = roc_auc_score(y_test, y_pred_proba_test_h1n1_opt[:,1])

# Print ROC AUC scores
print(f'AUROC XGB H1N1 Train: {roc_auc_train_xgb_h1n1_opt}'
      f'\nAUROC XGB H1N1 Test: {roc_auc_test_xgb_h1n1_opt}'
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      5258
#            1       0.72      0.52      0.61      1419
#
#     accuracy                           0.86      6677
#    macro avg       0.80      0.73      0.76      6677
# weighted avg       0.85      0.86      0.85      6677
# AUROC XGB H1N1 Train: 0.9490346958272265
# AUROC XGB H1N1 Test: 0.8713713470208557

# %%
# Seasonal w/ Optuna
xgb_se_opt = xgb.XGBClassifier(max_depth=5,
                               learning_rate=0.03217156742354802,
                               subsample=0.9882133490122514,
                               colsample_bytree=0.2723823854292983,
                               min_child_weight=0.0032118738505435636,
                               n_estimators=1000)

# Fit the model on the entire training set
xgb_se_opt.fit(X_train_se, y_train_se)

# Predict probabilities for the TRAIN set
y_pred_proba_train_se_opt = xgb_se_opt.predict_proba(X_train_se)

# Predict probabilities for the TEST set
y_pred_proba_test_se_opt = xgb_se_opt.predict_proba(X_test_se)

# Predict scores for TEST set
y_preds_test_se_opt = xgb_se_opt.predict(X_test_se)

# %%
# Display Confusion Matrix
conf_matrix_plot(xgb_se_opt, X_test_se, y_test_se)

# Classification Report (Seasonal)
print(classification_report(y_test_se, y_preds_test_se_opt))

# Seasonal Test
draw_roc_curve(y_test_se, y_pred_proba_test_se_opt[:,1])

# Calculate ROC AUC score for XGB
roc_auc_train_xgb_se_opt = roc_auc_score(y_train_se, y_pred_proba_train_se_opt[:,1])
roc_auc_test_xgb_se_opt = roc_auc_score(y_test_se, y_pred_proba_test_se_opt[:,1])

# Print ROC AUC scores
print(f'AUROC XGB Seasonal Train: {roc_auc_train_xgb_se_opt}'
      f'\nAUROC XGB Seasonal Test: {roc_auc_test_xgb_se_opt}'
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81      3524
#            1       0.80      0.76      0.78      3153
#
#     accuracy                           0.80      6677
#    macro avg       0.80      0.80      0.80      6677
# weighted avg       0.80      0.80      0.80      6677
# AUROC XGB Seasonal Train: 0.9174576718552068
# AUROC XGB Seasonal Test: 0.87415314964074

# %% [markdown]
# ## Predict on Unseen Data

# %%
# Join test_set_feat and train_set_lab by 'respondent_id' column
test_data = test_set_feat

test_data.head()
# Out:
#                h1n1_concern  ...  employment_occupation
# respondent_id                ...
# 26707                   2.0  ...               hfxkjkmi
# 26708                   1.0  ...               xqwwgdyp
# 26709                   2.0  ...               pvmttkik
# 26710                   1.0  ...                    NaN
# 26711                   3.0  ...               mxkfnird
#
# [5 rows x 35 columns]

# %%
# Use function to transform test set data
test_data_encoded = data_encoding(test_data)

# %%
# %%time

# Fit on Entire Training Dataset (H1N1)
xgb_h1n1_opt.fit(X, y)

# Fit on Entire Training Dataset (Seasonal)
xgb_se_opt.fit(X_se, y_se)
# Out:
# CPU times: user 3min 2s, sys: 453 ms, total: 3min 3s
# Wall time: 23 s
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1,
#               colsample_bytree=0.2723823854292983, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.03217156742354802,
#               max_bin=256, max_cat_to_onehot=4, max_delta_step=0, max_depth=5,
#               max_leaves=0, min_child_weight=0.0032118738505435636, missing=nan,
#               monotone_constraints='()', n_estimators=1000, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
# Predict probabilities for the unseen data (H1N1)
y_test_data_pred_proba_xgb_h1n1 = xgb_h1n1_opt.predict_proba(test_data_encoded)
print(y_test_data_pred_proba_xgb_h1n1[:,1])

# Predict probabilities for the unseen data (Seasonal)
y_test_data_pred_proba_xgb_se = xgb_se_opt.predict_proba(test_data_encoded)
print(y_test_data_pred_proba_xgb_se[:,1])
# Out:
# [0.0480988  0.04258372 0.18489295 ... 0.1334713  0.01091306 0.5827877 ]
# [0.22303073 0.0218151  0.701473   ... 0.15736638 0.29698724 0.5312235 ]

# %% [markdown]
# ## Export to CSV

# %%
# Insert columns into 'submission'
submission['h1n1_vaccine'] = y_test_data_pred_proba_xgb_h1n1[:,1]
submission['seasonal_vaccine'] = y_test_data_pred_proba_xgb_se[:,1]

submission.to_csv('Submission_Files/submission(CAIRO-XGB4).csv', index=False)

# %%
submission
# Out:
#        respondent_id  h1n1_vaccine  seasonal_vaccine
# 0              26707      0.048099          0.223031
# 1              26708      0.042584          0.021815
# 2              26709      0.184893          0.701473
# 3              26710      0.748476          0.903596
# 4              26711      0.330913          0.397775
# ...              ...           ...               ...
# 26703          53410      0.268905          0.444551
# 26704          53411      0.135569          0.362573
# 26705          53412      0.133471          0.157366
# 26706          53413      0.010913          0.296987
# 26707          53414      0.582788          0.531223
#
# [26708 rows x 3 columns]
